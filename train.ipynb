# %%
import torch
import numpy as np, cv2, pandas as pd, glob, time
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms, models, datasets
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
import gdown
import zipfile
import os

print("Đang tải fairface-img-margin025-trainval.zip...")
gdown.download('https://drive.google.com/uc?id=1Z1RqRo0_JiavaZw2yzZG6WETdZQ8qX86', 'fairface-img-margin025-trainval.zip', quiet=False)

print("Đang tải fairface-label-train.csv...")
gdown.download('https://drive.google.com/uc?id=1k5vvyREmHDW5TSM9QgB04Bvc8C8_7dl-', 'fairface-label-train.csv', quiet=False)

print("Đang tải fairface-label-val.csv...")
gdown.download('https://drive.google.com/uc?id=1_rtz1M1zhvS0d5vVoXUamnohB6cJ02iJ', 'fairface-label-val.csv', quiet=False)

zip_path = "fairface-img-margin025-trainval.zip"
extract_path = "fairface-img-margin025-trainval"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# Đang tải fairface-img-margin025-trainval.zip...
# Downloading...
# From (original): https://drive.google.com/uc?id=1Z1RqRo0_JiavaZw2yzZG6WETdZQ8qX86
# From (redirected): https://drive.google.com/uc?id=1Z1RqRo0_JiavaZw2yzZG6WETdZQ8qX86&confirm=t&uuid=7aadbe14-2cfd-49a1-a358-081d905a9243
# To: f:\PET_Project_CV\age_gender_prediction\fairface-img-margin025-trainval.zip
# 100%|██████████| 578M/578M [00:51<00:00, 11.3MB/s]
# Đang tải fairface-label-train.csv...
# Downloading...
# From: https://drive.google.com/uc?id=1k5vvyREmHDW5TSM9QgB04Bvc8C8_7dl-
# To: f:\PET_Project_CV\age_gender_prediction\fairface-label-train.csv
# 100%|██████████| 3.54M/3.54M [00:00<00:00, 8.65MB/s]
# Đang tải fairface-label-val.csv...
# Downloading...
# From: https://drive.google.com/uc?id=1_rtz1M1zhvS0d5vVoXUamnohB6cJ02iJ
# To: f:\PET_Project_CV\age_gender_prediction\fairface-label-val.csv
# 100%|██████████| 416k/416k [00:00<00:00, 3.80MB/s]

# %%
trn_df = pd.read_csv('./fairface-label-train.csv')
val_df = pd.read_csv('./fairface-label-val.csv')
trn_df.head()
# Out:
#           file  age  gender        race  service_test
# 0  train/1.jpg   59    Male  East Asian          True
# 1  train/2.jpg   39  Female      Indian         False
# 2  train/3.jpg   11  Female       Black         False
# 3  train/4.jpg   26  Female      Indian          True
# 4  train/5.jpg   26  Female      Indian          True

# %%
from torch.utils.data import Dataset, DataLoader
import cv2
IMAGE_SIZE = 224
class GenderAgeClass(Dataset):
    def __init__(self, df, tfms=None):
        self.df = df
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225])
    def __len__(self): return len(self.df)
    def __getitem__(self, ix):
        f = self.df.iloc[ix].squeeze()
        file = f.file
        gen = f.gender == 'Female'
        age = f.age
        im = cv2.imread(file)
        im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
        return im, age, gen

    def preprocess_image(self, im):
        im = cv2.resize(im, (IMAGE_SIZE, IMAGE_SIZE))
        im = torch.tensor(im).permute(2,0,1)
        im = self.normalize(im/255.)
        return im[None]

    def collate_fn(self, batch):
        'preprocess images, ages and genders'
        ims, ages, genders = [], [], []
        for im, age, gender in batch:
            im = self.preprocess_image(im)
            ims.append(im)

            ages.append(float(int(age)/80))
            genders.append(float(gender))

        ages, genders = [torch.tensor(x).to(device).float() for x in [ages, genders]]
        ims = torch.cat(ims).to(device)

        return ims, ages, genders

# %%
trn = GenderAgeClass(trn_df)
val = GenderAgeClass(val_df)

# %%
device='cuda'
train_loader = DataLoader(trn, batch_size=32, shuffle=True, drop_last=True, collate_fn=trn.collate_fn)
test_loader = DataLoader(val, batch_size=32, collate_fn=val.collate_fn)
a,b,c, = next(iter(train_loader))
print(a.shape, b.shape, c.shape)
# Out:
# torch.Size([32, 3, 224, 224]) torch.Size([32]) torch.Size([32])

# %%
def get_model():
    model = models.vgg16(pretrained = True)
    for param in model.parameters():
        param.requires_grad = False
    model.avgpool = nn.Sequential(
        nn.Conv2d(512,512, kernel_size=3),
        nn.MaxPool2d(2),
        nn.ReLU(),
        nn.Flatten()
    )
    class ageGenderClassifier(nn.Module):
        def __init__(self):
            super(ageGenderClassifier, self).__init__()
            self.intermediate = nn.Sequential(
                nn.Linear(2048,512),
                nn.ReLU(),
                nn.Dropout(0.4),
                nn.Linear(512,128),
                nn.ReLU(),
                nn.Dropout(0.4),
                nn.Linear(128,64),
                nn.ReLU(),
            )
            self.age_classifier = nn.Sequential(
                nn.Linear(64, 1),
                nn.Sigmoid()
            )
            self.gender_classifier = nn.Sequential(
                nn.Linear(64, 1),
                nn.Sigmoid()
            )
        def forward(self, x):
            x = self.intermediate(x)
            age = self.age_classifier(x)
            gender = self.gender_classifier(x)
            return gender, age

    model.classifier = ageGenderClassifier()

    gender_criterion = nn.BCELoss()
    age_criterion = nn.L1Loss()
    loss_functions = gender_criterion, age_criterion
    optimizer = torch.optim.Adam(model.parameters(), lr= 1e-4)

    return model.to(device), loss_functions, optimizer

model, loss_functions, optimizer = get_model()
# Out:
# f:\Anaconda\envs\model_train\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# f:\Anaconda\envs\model_train\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from torchsummary import summary
summary(model, input_size=(3,224,224), device=device)
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       (1,792)
# |    └─ReLU: 2-2                         --
# |    └─Conv2d: 2-3                       (36,928)
# |    └─ReLU: 2-4                         --
# |    └─MaxPool2d: 2-5                    --
# |    └─Conv2d: 2-6                       (73,856)
# |    └─ReLU: 2-7                         --
# |    └─Conv2d: 2-8                       (147,584)
# |    └─ReLU: 2-9                         --
# |    └─MaxPool2d: 2-10                   --
# |    └─Conv2d: 2-11                      (295,168)
# |    └─ReLU: 2-12                        --
# |    └─Conv2d: 2-13                      (590,080)
# |    └─ReLU: 2-14                        --
# |    └─Conv2d: 2-15                      (590,080)
# |    └─ReLU: 2-16                        --
# |    └─MaxPool2d: 2-17                   --
# |    └─Conv2d: 2-18                      (1,180,160)
# ...

# %%
def train_batch(data, model, optimizer, criteria):
    model.train()
    ims, age, gender = data
    optimizer.zero_grad()
    pred_gender, pred_age = model(ims)
    gender_criterion, age_criterion = criteria
    gender_loss = gender_criterion(pred_gender.squeeze(), gender)
    age_loss = age_criterion(pred_age.squeeze(), age)
    total_loss = gender_loss + age_loss
    total_loss.backward()
    optimizer.step()
    return total_loss

def validate_batch(data, model, criteria):
    model.eval()
    ims, age, gender = data
    with torch.no_grad():
      pred_gender, pred_age = model(ims)
    gender_criterion, age_criterion = criteria
    gender_loss = gender_criterion(pred_gender.squeeze(), gender)
    age_loss = age_criterion(pred_age.squeeze(), age)
    total_loss = gender_loss + age_loss
    pred_gender = (pred_gender > 0.5).squeeze()
    gender_acc = (pred_gender == gender).float().sum()
    age_mae = torch.abs(age - pred_age).float().sum()
    return total_loss, gender_acc, age_mae

# %%
def train_model():
    model, criteria, optimizer = get_model()
    val_gender_accuracies = []
    val_age_maes = []
    train_losses = []
    val_losses = []
    
    n_epochs = 5
    best_test_loss = float('inf')
    start = time.time()
    
    os.makedirs('saved_models', exist_ok=True)
    
    for epoch in range(n_epochs):
        epoch_train_loss, epoch_test_loss = 0, 0
        val_age_mae, val_gender_acc, ctr = 0, 0, 0
        
        # Training
        for ix, data in enumerate(train_loader):
            loss = train_batch(data, model, optimizer, criteria)
            epoch_train_loss += loss.item()
        
        # Validation
        for ix, data in enumerate(test_loader):
            loss, gender_acc, age_mae = validate_batch(data, model, criteria)
            epoch_test_loss += loss.item()
            val_age_mae += age_mae
            val_gender_acc += gender_acc
            ctr += len(data[0])
        
        val_age_mae /= ctr
        val_gender_acc /= ctr
        epoch_train_loss /= len(train_loader)
        epoch_test_loss /= len(test_loader)
        
        elapsed = time.time() - start
        
        print(f'{epoch+1}/{n_epochs} ({elapsed:.2f}s - {(n_epochs-epoch)*(elapsed/(epoch+1)):.2f}s remaining)')
        info = f'Epoch: {epoch+1:03d}\tTrain Loss: {epoch_train_loss:.3f}\tTest: {epoch_test_loss:.3f}'
        info += f'\nGender Accuracy: {val_gender_acc*100:.2f}%\tAge MAE: {val_age_mae:.2f}\n'
        print(info)
        
        val_gender_accuracies.append(val_gender_acc)
        val_age_maes.append(val_age_mae)
        train_losses.append(epoch_train_loss)
        val_losses.append(epoch_test_loss)
        
        # Save best model
        if epoch_test_loss < best_test_loss:
            best_test_loss = epoch_test_loss
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_loss': epoch_train_loss,
                'val_loss': epoch_test_loss,
                'val_gender_acc': val_gender_acc,
                'val_age_mae': val_age_mae,
            }, 'saved_models/best_model.pth')
            print(f"Saved best model with validation loss: {best_test_loss:.4f}")
        
        # Save checkpoint mỗi epoch
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': epoch_train_loss,
            'val_loss': epoch_test_loss,
            'val_gender_acc': val_gender_acc,
            'val_age_mae': val_age_mae,
        }, f'saved_models/checkpoint_epoch_{epoch+1}.pth')
    
    # Lưu model cuối cùng
    torch.save({
        'epoch': n_epochs-1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'val_gender_accuracies': val_gender_accuracies,
        'val_age_maes': val_age_maes,
    }, 'saved_models/final_model.pth')
    
    print("Training completed!")
    print(f"Best validation loss: {best_test_loss:.4f}")
    
    return model, val_gender_accuracies, val_age_maes

# %%
model, val_gender_accuracies, val_age_maes = train_model()
    
epochs = np.arange(1, len(val_gender_accuracies) + 1)
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax = ax.flat
ax[0].plot(epochs, [v.item() for v in val_gender_accuracies], 'bo-')
ax[1].plot(epochs, [v.item() for v in val_age_maes], 'r-')
ax[0].set_xlabel('Epochs')
ax[1].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[1].set_ylabel('MAE')
ax[0].set_title('Validation Gender Accuracy')
ax[1].set_title('Validation Age Mean-Absolute-Error')
ax[0].grid(True)
ax[1].grid(True)
plt.tight_layout()
plt.savefig('training_results.png')
plt.show()
# Out:
# 1/5 (1431.98s - 7159.88s remaining)
# Epoch: 001	Train Loss: 0.553	Test: 0.469
# Gender Accuracy: 83.51%	Age MAE: 6.21
#
# Saved best model with validation loss: 0.4692
# 2/5 (2542.32s - 5084.63s remaining)
# Epoch: 002	Train Loss: 0.402	Test: 0.454
# Gender Accuracy: 84.32%	Age MAE: 6.23
#
# Saved best model with validation loss: 0.4543
# 3/5 (4059.74s - 4059.74s remaining)
# Epoch: 003	Train Loss: 0.285	Test: 0.493
# Gender Accuracy: 84.16%	Age MAE: 6.35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model, val_gender_accuracies, val_age_maes = train_model()
#       3 epochs = np.arange(1, len(val_gender_accuracies) + 1)
#       4 fig, ax = plt.subplots(1, 2, figsize=(12, 5))
#
# Cell In[18], line 19, in train_model()
#      16 val_age_mae, val_gender_acc, ctr = 0, 0, 0
#      18 # Training
# ---> 19 for ix, data in enumerate(train_loader):
# ...

# %%
im = cv2.imread('./val/10115.jpg')
im = trn.preprocess_image(im).to(device)
gender, age = model(im)
pred_gender = gender.to('cpu').detach().numpy()
pred_age = age.to('cpu').detach().numpy()
im = cv2.imread('./val/10115.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)
print('predicted gender:',np.where(pred_gender[0][0]<0.5,'Male','Female'), '; Predicted age', int(pred_age[0][0]*80))
# Out:
# predicted gender: Male ; Predicted age 39
